# %%
print("Hello World")
# Out:
# Hello World

# %% [raw]
# print(Hello world)

# %%
print("welcome","to","phython")
# Out:
# welcome to phython

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=3
b=2
print(a-b)
# Out:
# 1

# %%
a=4
b=6
print(a*b)
# Out:
# 24

# %%
a=6
b=2
print(a/b)
# Out:
# 3.0

# %%
a=4
b=5
print(a%b)
# Out:
# 4

# %%
a=5
b=2
print(a//b)
# Out:
# 2

# %%
a=int(input("Enter the value of a"))
b=int(input("Enter the value of b"))
print(a+b)
# Out:
# Enter the value of a 4
# Enter the value of b 6
# 10

# %%
a=(input("Enter the value of a"))
b=(input("Enter the value of b"))
print(a+b)
# Out:
# Enter the value of a 4
# Enter the value of b 6
# 46

# %%
p=float(input("Enter the principle amount"))
r=float(input("Enter the rate of interest"))
t=float(input("Enter the time"))
SI=(p*t*r)/100
print("Simple interest is",SI)
# Out:
# Enter the principle amount 45000
# Enter the rate of interest 3
# Enter the time 2
# Simple interest is 2700.0

# %%
a=int(input("Enter the value of a"))
b=int(input("Enter the value of b"))
print("values before swapping",a,b)
temp=a
a=b
b=temp
print("Values after swapping is ",a,b)
# Out:
# Enter the value of a 3
# Enter the value of b 4
# values before swapping 3 4
# Values after swapping is  4 3

# %%
a=5
b=6
print("values before swapping",a,b)
a,b=b,a
print("Values after swapping is ",a,b)
# Out:
# values before swapping 5 6
# Values after swapping is  6 5

# %%
a=int(input("Enter the value of a"))
square=a*a
print("The square of the number is",square)
# Out:
# Enter the value of a 2
# The square of the number is 4

# %%
a=3
b=5
c=6
average=(a+b+c)/3
print("The average is",average)
# Out:
# The average is 4.666666666666667

# %%
celsius=37.5
farenhite=(celsius*1.8)*32
print("The farenhite is",farenhite)
# Out:
# The farenhite is 2160.0

# %%
a=6
b=4
print("Addition",a+b)
print("subtraction",a-b)
print("multiplication",a*b)
print("Division",a/b)
# Out:
# Addition 10
# subtraction 2
# multiplication 24
# Division 1.5

# %%
num=int(input("Enter the value of num"))
if(num>0):
  print("The given number is positive")
elif(num<0):
  print("The given number is negative")
else:
  print("The given number is 0")
# Out:
# Enter the value of num -5
# The given number is negative

# %%
year=int(input("Enter teh year"))
if((year%4==0)and(year%100!=0)):
 print("It is a leap year")
else:
 print("It is not a leap year")
# Out:
# Enter teh year 2024
# It is a leap year

# %%
alph=str(input("Enter a alphabet"))
if alph in['A','E','I','O','U'] or ['a','e','i','o','u']:
   print("The given alphabet is vowel")
else:
          print("THe given alphabet is a constant")
# Out:
# Enter a alphabet a
# The given alphabet is vowel

# %%
marks=int(input("Enter  your marks"))
if(marks>=90):
    print("Grade A")
elif(marks>=80):
    print("Grade B")
elif(marks>=70):
    print("Grade C")
elif(marks>=60):
    print("Grade D")
else:
    print("Fail")
# Out:
# Enter  your marks 89
# Grade B

# %%
num=int(input("Enter a number"))
if(num%5==0) and(num%11==0):
    print("The given number is divisible by 5 and 11")
else:
    print("The given number is not divisible by 5 and 11")
# Out:
# Enter a number 56
# The given number is not divisible by 5 and 11

# %%
val=str(input("ENter any value"))
if val.isalpha():
    print("The entered value is a alphabet")
elif val.isint():
    print("The entered value is a integer")
else:
    print("It is a special character")
# Out:
# ENter any value h
# The entered value is a alphabet

# %%
num=int(input("ENter a number"))
fact=1
if(num<0):
    print("The given number does not have a factorial")
else:
    for i in range(1,num+1):
      fact=fact*i
    print("The factorial is",fact)
# Out:
# ENter a number 5
# The factorial is 120

# %%
num=int(input("Enter a number"))
if(num%3==0) :
    print("The given number is divisible by 3 ")
else:
    print("The given number is not divisible by 3 ")
# Out:
# Enter a number 6
# The given number is divisible by 3

# %%
p=float(input("Enter the principle amount"))
r=float(input("Enter the rate of interest"))
t=float(input("Enter the time"))
SI=(p*t*r)/100
print("Simple interest is",SI)
# Out:
# Enter the principle amount 45000
# Enter the rate of interest 3
# Enter the time 8
# Simple interest is 10800.0
